# %%
import os
import pandas as pd
os.chdir("/content/sample_data/")
data = pd.read_csv("trainmod.csv")

# %% [markdown]
# # Inspección de los datos

# %%
data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Crisis            object
# Reforma            int64
# Length: 83, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 83 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  X1stFlrSF      1460 non-null   int64
#  44  X2ndFlrSF      1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  X3SsnPorch     1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
#  81  Crisis         1460 non-null   object
#  82  Reforma        1460 non-null   int64
# dtypes: float64(3), int64(36), object(44)
# memory usage: 946.8+ KB

# %% [markdown]
# # Selección de las columnas numéricas

# %% [markdown]
# ### Método 1 seleccionando los tipos

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

datanum = data.select_dtypes(include=numerics)
datanum.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# X1stFlrSF          int64
# X2ndFlrSF          int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# X3SsnPorch         int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SalePrice          int64
# Reforma            int64
# dtype: object

# %% [markdown]
# ### Método 2, a partir de los nombres de las columnas de describe()

# %%
data.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# X1stFlrSF      1460.0    1162.626712    386.587738    334.0     882.00
# X2ndFlrSF      1460.0     346.992466    436.528436      0.0       0.00
# LowQualFinSF   1460.0       5.844521     48.623081      0.0       0.00
SSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'X1stFlrSF', 'X2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', 'X3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'Reforma'],
#       dtype='object')

# %%
data_num = data[data.describe().columns]

# %%
data_num
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  OpenPorchSF  \
# 0          2003          2003       196.0         706  ...           61
# 1          1976          1976         0.0         978  ...            0
# 2          2001          2002       162.0         486  ...           42
# 3          1915          1970         0.0         216  ...           35
# 4          2000          2000       350.0         655  ...           84
# ...         ...           ...         ...         ...  ...          ...
# 1455       1999          2000         0.0           0  ...           40
# 1456       1978          1988       119.0         790  ...            0
# 1457       1941          2006         0.0         275  ...           60
# 1458       1950          1996         0.0          49  ...            0
# 1459       1965          1965         0.0         830  ...           68
#
#       EnclosedPorch  X3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  \
# 0                 0           0            0         0        0       2
# 1                 0           0            0         0        0       5
# 2                 0           0            0         0        0       9
# 3               272           0            0         0        0       2
# 4                 0           0            0         0        0      12
# ...             ...         ...          ...       ...      ...     ...
# 1455              0           0            0         0        0       8
# 1456              0           0            0         0        0       2
# 1457              0           0            0         0     2500       5
# 1458            112           0            0         0        0       4
# 1459              0           0            0         0        0       6
#
#       YrSold  SalePrice  Reforma
# 0       2008     208500        5
# 1       2007     181500       31
# 2       2008     223500        6
# 3       2006     140000       36
# 4       2008     250000        8
# ...      ...        ...      ...
# 1455    2007     175000        7
# 1456    2010     210000       22
# 1457    2010     266500        4
# 1458    2010     142125       14
# 1459    2008     147500       43
#
# [1460 rows x 39 columns]

# %% [markdown]
# # Representación gráfica
# Ralizar un boxplot de dichos datos.

# %%
data_num.plot(kind='box');

# %% [markdown]
# ### Representación de una única variable
#
# Con el nombre de la columna

# %%
data_num["SalePrice"].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Con el índice de la columna

# %%
data_num.iloc[:,4].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# YearRemodAdd     1994.0    2004.00    2010.0
# MasVnrArea          0.0     166.00    1600.0
# BsmtFinSF1        383.5     712.25    5644.0
# BsmtFinSF2          0.0       0.00    1474.0
# BsmtUnfSF         477.5     808.00    2336.0
# TotalBsmtSF       991.5    1298.25    6110.0
# X1stFlrSF        1087.0    1391.25    4692.0
# X2ndFlrSF           0.0     728.00    2065.0
# LowQualFinSF        0.0       0.00     572.0
# GrLivArea        1464.0    1776.75    5642.0
# BsmtFullBath        0.0       1.00       3.0
# BsmtHalfBath        0.0       0.00       2.0
# FullBath            2.0       2.00       3.0
# HalfBath            0.0       1.00       2.0
# BedroomAbvGr        3.0       3.00       8.0
# KitchenAbvGr        1.0       1.00       3.0
# TotRmsAbvGrd        6.0       7.00      14.0
# Fireplaces          1.0       1.00       3.0
# GarageYrBlt      1980.0    2002.00    2010.0
# GarageCars          2.0       2.00       4.0
# GarageArea        480.0     576.00    1418.0
# WoodDeckSF          0.0     168.00     857.0
# OpenPorchSF        25.0      68.00     547.0
# EnclosedPorch       0.0       0.00     552.0
# X3SsnPorch          0.0       0.00     508.0
# ScreenPorch         0.0       0.00     480.0
# PoolArea            0.0       0.00     738.0
# MiscVal             0.0       0.00   15500.0
# MoSold              6.0       8.00      12.0
# YrSold           2008.0    2009.00    2010.0
# SalePrice      163000.0  214000.00  755000.0
# Reforma            14.0      41.00      60.0

# %% [markdown]
# Viendo los valores únicos de las variables puedo detectar qué variables son realmente numéricas y cuales son asimilables a categóricas
#
# Por ejemplo, OverallQual y OverallCond son notas del 1 al 10

# %%
data_num["OverallQual"].unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2])

# %%
data_num["OverallCond"].unique()
# Out:
# array([5, 8, 6, 7, 4, 2, 3, 9, 1])

# %% [markdown]
# YearBuilt es numérica, pero sería conveniente transformarla en "Antigüedad" de la vivienda para hacer cálculos

# %%
data_num["YearBuilt"].unique()
# Out:
# array([2003, 1976, 2001, 1915, 2000, 1993, 2004, 1973, 1931, 1939, 1965,
#        2005, 1962, 2006, 1960, 1929, 1970, 1967, 1958, 1930, 2002, 1968,
#        2007, 1951, 1957, 1927, 1920, 1966, 1959, 1994, 1954, 1953, 1955,
#        1983, 1975, 1997, 1934, 1963, 1981, 1964, 1999, 1972, 1921, 1945,
#        1982, 1998, 1956, 1948, 1910, 1995, 1991, 2009, 1950, 1961, 1977,
#        1985, 1979, 1885, 1919, 1990, 1969, 1935, 1988, 1971, 1952, 1936,
#        1923, 1924, 1984, 1926, 1940, 1941, 1987, 1986, 2008, 1908, 1892,
#        1916, 1932, 1918, 1912, 1947, 1925, 1900, 1980, 1989, 1992, 1949,
#        1880, 1928, 1978, 1922, 1996, 2010, 1946, 1913, 1937, 1942, 1938,
#        1974, 1893, 1914, 1906, 1890, 1898, 1904, 1882, 1875, 1911, 1917,
#        1872, 1905])

# %% [markdown]
# Estas variables, en cambio, serían asimilables a categorías.

# %%
data_num["BsmtFullBath"].unique()
# Out:
# array([1, 0, 2, 3])

# %%
data_num["FullBath"].unique()
# Out:
# array([2, 1, 3, 0])

# %%
data_num["Fireplaces"].unique()
# Out:
# array([0, 1, 2, 3])

# %%
data_num["GarageCars"].unique()
# Out:
# array([2, 3, 1, 0, 4])

# %% [markdown]
# Elimino variables categóricas

# %%
data_num2=data_num.drop(columns=['Id','OverallQual', 'OverallCond' , 'YearBuilt', 'YearRemodAdd','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','TotRmsAbvGrd','Fireplaces' ,'GarageYrBlt', 'GarageCars','MoSold','YrSold'])

# %%
data_num2
# Out:
#       MSSubClass  LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# 0             60         65.0     8450       196.0         706           0
# 1             20         80.0     9600         0.0         978           0
# 2             60         68.0    11250       162.0         486           0
# 3             70         60.0     9550         0.0         216           0
# 4             60         84.0    14260       350.0         655           0
# ...          ...          ...      ...         ...         ...         ...
# 1455          60         62.0     7917         0.0           0           0
# 1456          20         85.0    13175       119.0         790         163
# 1457          70         66.0     9042         0.0         275           0
# 1458          20         68.0     9717         0.0          49        1029
# 1459          20         75.0     9937         0.0         830         290
#
#       BsmtUnfSF  TotalBsmtSF  X1stFlrSF  X2ndFlrSF  ...  GarageArea  \
# 0           150          856        856        854  ...         548
# 1           284         1262       1262          0  ...         460
# 2           434          920        920        866  ...         608
# 3           540          756        961        756  ...         642
# 4           490         1145       1145       1053  ...         836
# ...         ...          ...        ...        ...  ...         ...
# 1455        953          953        953        694  ...         460
# 1456        589         1542       2073          0  ...         500
# 1457        877         1152       1188       1152  ...         252
# 1458          0         1078       1078          0  ...         240
# 1459        136         1256       1256          0  ...         276
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  X3SsnPorch  ScreenPorch  \
# 0              0           61              0           0            0
# 1            298            0              0           0            0
# 2              0           42              0           0            0
# 3              0           35            272           0            0
# 4            192           84              0           0            0
# ...          ...          ...            ...         ...          ...
# 1455           0           40              0           0            0
# 1456         349            0              0           0            0
# 1457           0           60              0           0            0
# 1458         366            0            112           0            0
# 1459         736           68              0           0            0
#
#       PoolArea  MiscVal  SalePrice  Reforma
# 0            0        0     208500        5
# 1            0        0     181500       31
# 2            0        0     223500        6
# 3            0        0     140000       36
# 4            0        0     250000        8
# ...        ...      ...        ...      ...
# 1455         0        0     175000        7
# 1456         0        0     210000       22
# 1457         0     2500     266500        4
# 1458         0        0     142125       14
# 1459         0        0     147500       43
#
# [1460 rows x 23 columns]

# %% [markdown]
# Realizo más Boxplots

# %%
b1=data_num2.iloc[:,0:6].plot(kind='box')
b2=data_num2.iloc[:,7:14].plot(kind='box')
b3=data_num2.iloc[:,15:21].plot(kind='box')
#6. Realizar el boxplot por grupos y en caso de ser necesario eliminar o modificar alguna
#variable hasta extraer conclusiones fiables.
data_num3 = data_num2.drop(columns=["LotArea", "MiscVal"])

# %% [markdown]
# Eliminando esas variables que distorsionan los gráficos, obtengo boxplots más centrados

# %%
b1=data_num3.iloc[:,0:6].plot(kind='box')
b2=data_num3.iloc[:,7:14].plot(kind='box')
b3=data_num3.iloc[:,15:21].plot(kind='box')

# %% [markdown]
# # Eliminación de Outliers mediante el rango intercuartílico en la columna SalePrice

# %%
# Calcular el rango intercuartílico (IQR)
Q1 = data_num["SalePrice"].quantile(0.25)
Q3 = data_num["SalePrice"].quantile(0.75)
IQR = Q3 - Q1
print(IQR, Q1, Q3)
# Out:
# 84025.0 129975.0 214000.0

# %%
# Definir los límites para identificar outliers
limite_inferior = Q1 - 2 * IQR
limite_superior = Q3 + 2 * IQR

# Filtrar los outliers
outliers = data_num[(data_num["SalePrice"] < limite_inferior) | (data_num["SalePrice"] > limite_superior)]
no_outliers = data_num[~((data_num["SalePrice"] < limite_inferior) | (data_num["SalePrice"] > limite_superior))]

# Imprimir los resultados
print("Límite inferior:", limite_inferior)
print("Límite superior:", limite_superior)
print("Número de outliers:", len(outliers))
print("Outliers:")
print(outliers)
# Out:
# Límite inferior: -38075.0
# Límite superior: 382050.0
# Número de outliers: 38
# Outliers:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 53      54          20         68.0    50271            9            5
# 58      59          60         66.0    13682           10            5
# 112    113          60         77.0     9965            7            5
# 161    162          60        110.0    13688            9            5
# 178    179          20         63.0    17423            9            5
# 185    186          75         90.0    22950           10            9
# 224    225          20        103.0    13472           10            5
# 231    232          60        174.0    15138            8            5
# 278    279          20        107.0    14450            9            5
# 349    350          60         56.0    20431            9            5
# 378    379          20         88.0    11394            9            2
# 389    390          60         96.0    12474           10            5
# 440    441          20        105.0    15431           10            5
# 473    474          20        110.0    14977            8            5
# 496    497          20          NaN    12692            8            5
# 515    516          20         94.0    12220           10            5
# 527    528          60         67.0    14948            9            5
# 591    592          60         97.0    13478           10            5
# 661    662          60         52.0    46589            8            7
# 664    665          20         49.0    20896            8            5
# 688    689          20         60.0     8089            8            6
# 691    692          60        104.0    21535           10            6
# 769    770          60         47.0    53504            8            5
# 774    775          20        110.0    14226            8            5
# 798    799          60        104.0    13518            9            5
# 803    804          60        107.0    13891            9            5
# 825    826          20        114.0    14803           10            5
# 898    899          20        100.0    12919            9            5
# 987    988          20         83.0    10159            9            5
# 1046  1047          60         85.0    16056            9            5
# 1142  1143          60         77.0     9965            8            5
# 1169  1170          60        118.0    35760           10            5
# 1181  1182         120         64.0     5587            8            5
# 1182  1183          60        160.0    15623           10            5
# 1243  1244          20        107.0    13891           10            5
# 1353  1354          50         56.0    14720            8            5
# 1373  1374          20          NaN    11400           10            5
# 1437  1438          20         96.0    12444            8            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1
# 440     2009     555000        1
# 473     2007     440000        0
# 496     2007     430000       14
# 515     2009     402861        0
# 527     2008     446261        0
# 591     2009     451950        1
# 661     2009     402000        4
# 664     2006     423000        0
# 688     2007     392000        0
# 691     2007     755000       12
# 769     2010     538000        7
# 774     2007     395000        1
# 798     2009     485000        0
# 803     2009     582933        0
# 825     2008     385000        0
# 898     2010     611657        0
# 987     2010     395192        0
# 1046    2006     556581        0
# 1142    2007     424870        0
# 1169    2006     625000       10
# 1181    2008     392500        0
# 1182    2007     745000       11
# 1243    2006     465000        0
# 1353    2010     410000       14
# 1373    2007     466500        5
# 1437    2008     394617        0
#
# [38 rows x 39 columns]

# %% [markdown]
# Puedo concatenar los datos que no tienen outliers con los datos que sí los tienen, y a los cuales les he eliminado la columna SalePrice.
#
# De esa manera, las casillas de la columna que tenían valores excesivos, están ocupadas por "NaN"

# %%
pd.concat([outliers.drop(columns=["SalePrice"]), no_outliers], sort=True)
# Out:
#       BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  BsmtFullBath  BsmtHalfBath  \
# 53               0        1810           0             2             0
# 58               3           0           0             0             0
# 112              4         984           0             1             0
# 161              3        1016           0             1             0
# 178              1        1904           0             1             0
# ...            ...         ...         ...           ...           ...
# 1455             3           0           0             0             0
# 1456             3         790         163             1             0
# 1457             4         275           0             0             0
# 1458             2          49        1029             1             0
# 1459             3         830         290             1             0
#
#       BsmtUnfSF  EnclosedPorch  Fireplaces  FullBath  GarageArea  ...  \
# 53           32              0           1         0         894  ...
# 58         1410             37           1         3         641  ...
# 112         280              0           1         2         792  ...
# 161         556              0           2         2         726  ...
# 178         312              0           1         2        1166  ...
# ...         ...            ...         ...       ...         ...  ...
# 1455        953              0           1         2         460  ...
# 1456        589              0           2         2         500  ...
# 1457        877              0           2         2         252  ...
# 1458          0            112           0         1         240  ...
# 1459        136              0           0         1         276  ...
#
#       ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  X1stFlrSF  \
# 53              0             5         1842         857       1842
# 58              0            10         1410         192       1426
# 112           168            10         1264         120       1282
# 161             0            10         1572         400       1572
# 178             0             9         2216           0       2234
# ...           ...           ...          ...         ...        ...
# 1455            0             7          953           0        953
# 1456            0             7         1542         349       2073
# 1457            0             9         1152           0       1188
# 1458            0             5         1078         366       1078
# 1459            0             6         1256         736       1256
#
#       X2ndFlrSF  X3SsnPorch  YearBuilt  YearRemodAdd  YrSold
# 53            0           0       1981          1987    2006
# 58         1519           0       2006          2006    2006
# 112        1414           0       2007          2007    2007
# 161        1096           0       2003          2004    2008
# 178           0           0       2008          2009    2009
# ...         ...         ...        ...           ...     ...
# 1455        694           0       1999          2000    2007
# 1456          0           0       1978          1988    2010
# 1457       1152           0       1941          2006    2010
# 1458          0           0       1950          1996    2010
# 1459          0           0       1965          1965    2008
#
# [1460 rows x 39 columns]

# %% [markdown]
# También puedo quedarme con el índice de los outliers...

# %%
outliers.index
# Out:
# Int64Index([  53,   58,  112,  161,  178,  185,  224,  231,  278,  349,  378,
#              389,  440,  473,  496,  515,  527,  591,  661,  664,  688,  691,
#              769,  774,  798,  803,  825,  898,  987, 1046, 1142, 1169, 1181,
#             1182, 1243, 1353, 1373, 1437],
#            dtype='int64')

# %% [markdown]
# ...y usar ese índice para ubicar en las casillas

# %%
data["SalePrice"].loc[outliers.index] = limite_superior
# Out:
# <ipython-input-28-e8d51b8ce614>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["SalePrice"].loc[outliers.index] = limite_superior

# %% [markdown]
# Comprobamos la modificación

# %%
data.iloc[50:60,:]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 50  51          60       RL          NaN    13869   Pave   NaN      IR2
# 51  52          50       RM         52.0     6240   Pave   NaN      Reg
# 52  53          90       RM        110.0     8472   Grvl   NaN      IR2
# 53  54          20       RL         68.0    50271   Pave   NaN      IR1
# 54  55          80       RL         60.0     7134   Pave   NaN      Reg
# 55  56          20       RL        100.0    10175   Pave   NaN      IR1
# 56  57         160       FV         24.0     2645   Pave  Pave      Reg
# 57  58          60       RL         89.0    11645   Pave   NaN      IR1
# 58  59          60       RL         66.0    13682   Pave   NaN      IR2
# 59  60          20       RL         60.0     7200   Pave   NaN      Reg
#
#    LandContour Utilities  ...  Fence MiscFeature MiscVal MoSold YrSold  \
# 50         Lvl    AllPub  ...    NaN         NaN       0      7   2007
# 51         Lvl    AllPub  ...  MnPrv        Shed     400      9   2006
# 52         Bnk    AllPub  ...    NaN         NaN       0      5   2010
# 53         Low    AllPub  ...    NaN         NaN       0     11   2006
# 54         Bnk    AllPub  ...  MnPrv         NaN       0      2   2007
# 55         Lvl    AllPub  ...    NaN         NaN       0      7   2008
# 56         Lvl    AllPub  ...    NaN         NaN       0      8   2009
# 57         Lvl    AllPub  ...    NaN         NaN       0      8   2006
# 58         HLS    AllPub  ...    NaN         NaN       0     10   2006
# 59         Bnk    AllPub  ...  MnPrv         NaN       0      1   2008
#
#    SaleType SaleCondition  SalePrice  Crisis  Reforma
# 50       WD        Normal     177000      No       10
# 51       WD        Normal     114500      No       56
# 52       WD        Normal     110000      Si       47
# 53       WD        Normal     382050      No       19
# 54       WD        Normal     130000      No       52
# 55       WD        Normal     180500      Si       44
# 56       WD       Abnorml     172500      Si        9
# 57       WD        Normal     196500      No        2
# 58      New       Partial     382050      No        0
# 59       WD        Normal     124900      Si       36
#
# [10 rows x 83 columns]

# %% [markdown]
# # Eliminación de Outliers mediante la desviación típica en la columna SalePrice

# %%
# Calcular la media y la desviación típica
media = data_num["SalePrice"].mean()
desviacion_tipica = data_num["SalePrice"].std()

# Definir los límites para identificar outliers
limite_inferior = media - 3 * desviacion_tipica
limite_superior = media + 3 * desviacion_tipica

# %%
# Filtrar los outliers
outliers = data_num[(data_num["SalePrice"] < limite_inferior) | (data_num["SalePrice"] > limite_superior)]
no_outliers = data_num[~((data_num["SalePrice"] < limite_inferior) | (data_num["SalePrice"] > limite_superior))]

# Imprimir los resultados
print("Límite inferior:", limite_inferior)
print("Límite superior:", limite_superior)
print("Número de outliers:", len(outliers))
print("Outliers:")
print(outliers)
# Out:
# Límite inferior: -57406.31275824891
# Límite superior: 419248.70453907084
# Número de outliers: 22
# Outliers:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond
# 185     2006     475000       13
# 349     2006     437154        0
# 389     2008     426000        0
# 440     2009     555000        1
# 473     2007     440000        0
# 496     2007     430000       14
# 527     2008     446261        0
# 591     2009     451950        1
# 664     2006     423000        0
# 691     2007     755000       12
# 769     2010     538000        7
# 798     2009     485000        0
# 803     2009     582933        0
# 898     2010     611657        0
# 1046    2006     556581        0
# 1142    2007     424870        0
# 1169    2006     625000       10
# 1182    2007     745000       11
# 1243    2006     465000        0
# 1373    2007     466500        5
#
# [22 rows x 39 columns]

# %%
outliers.index
# Out:
# Int64Index([  58,  178,  185,  349,  389,  440,  473,  496,  527,  591,  664,
#              691,  769,  798,  803,  898, 1046, 1142, 1169, 1182, 1243, 1373],
#            dtype='int64')

# %%
limite_superior
# Out:
# 419248.70453907084

# %%
data["SalePrice"].loc[outliers.index] = limite_superior
# Out:
# <ipython-input-34-e8d51b8ce614>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["SalePrice"].loc[outliers.index] = limite_superior

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ...  Fence MiscFeature MiscVal MoSold YrSold  \
# 0            Lvl    AllPub  ...    NaN         NaN       0      2   2008
# 1            Lvl    AllPub  ...    NaN         NaN       0      5   2007
# 2            Lvl    AllPub  ...    NaN         NaN       0      9   2008
# 3            Lvl    AllPub  ...    NaN         NaN       0      2   2006
# 4            Lvl    AllPub  ...    NaN         NaN       0     12   2008
# ...          ...       ...  ...    ...         ...     ...    ...    ...
# 1455         Lvl    AllPub  ...    NaN         NaN       0      8   2007
# 1456         Lvl    AllPub  ...  MnPrv         NaN       0      2   2010
# 1457         Lvl    AllPub  ...  GdPrv        Shed    2500      5   2010
# 1458         Lvl    AllPub  ...    NaN         NaN       0      4   2010
# 1459         Lvl    AllPub  ...    NaN         NaN       0      6   2008
#
#      SaleType SaleCondition  SalePrice  Crisis  Reforma
# 0          WD        Normal   208500.0      Si        5
# 1          WD        Normal   181500.0      No       31
# 2          WD        Normal   223500.0      Si        6
# 3          WD       Abnorml   140000.0      No       36
# 4          WD        Normal   250000.0      Si        8
# ...       ...           ...        ...     ...      ...
# 1455       WD        Normal   175000.0      No        7
# 1456       WD        Normal   210000.0      Si       22
# 1457       WD        Normal   266500.0      Si        4
# 1458       WD        Normal   142125.0      Si       14
# 1459       WD        Normal   147500.0      Si       43
#
# [1460 rows x 83 columns]

# %%
data.iloc[50:60,:]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 50  51          60       RL          NaN    13869   Pave   NaN      IR2
# 51  52          50       RM         52.0     6240   Pave   NaN      Reg
# 52  53          90       RM        110.0     8472   Grvl   NaN      IR2
# 53  54          20       RL         68.0    50271   Pave   NaN      IR1
# 54  55          80       RL         60.0     7134   Pave   NaN      Reg
# 55  56          20       RL        100.0    10175   Pave   NaN      IR1
# 56  57         160       FV         24.0     2645   Pave  Pave      Reg
# 57  58          60       RL         89.0    11645   Pave   NaN      IR1
# 58  59          60       RL         66.0    13682   Pave   NaN      IR2
# 59  60          20       RL         60.0     7200   Pave   NaN      Reg
#
#    LandContour Utilities  ...  Fence MiscFeature MiscVal MoSold YrSold  \
# 50         Lvl    AllPub  ...    NaN         NaN       0      7   2007
# 51         Lvl    AllPub  ...  MnPrv        Shed     400      9   2006
# 52         Bnk    AllPub  ...    NaN         NaN       0      5   2010
# 53         Low    AllPub  ...    NaN         NaN       0     11   2006
# 54         Bnk    AllPub  ...  MnPrv         NaN       0      2   2007
# 55         Lvl    AllPub  ...    NaN         NaN       0      7   2008
# 56         Lvl    AllPub  ...    NaN         NaN       0      8   2009
# 57         Lvl    AllPub  ...    NaN         NaN       0      8   2006
# 58         HLS    AllPub  ...    NaN         NaN       0     10   2006
# 59         Bnk    AllPub  ...  MnPrv         NaN       0      1   2008
#
#    SaleType SaleCondition      SalePrice  Crisis  Reforma
# 50       WD        Normal  177000.000000      No       10
# 51       WD        Normal  114500.000000      No       56
# 52       WD        Normal  110000.000000      Si       47
# 53       WD        Normal  382050.000000      No       19
# 54       WD        Normal  130000.000000      No       52
# 55       WD        Normal  180500.000000      Si       44
# 56       WD       Abnorml  172500.000000      Si        9
# 57       WD        Normal  196500.000000      No        2
# 58      New       Partial  419248.704539      No        0
# 59       WD        Normal  124900.000000      Si       36
#
# [10 rows x 83 columns]

# %% [markdown]
# # Eliminación de Outliers mediante la desviación típica en cualquier columna usando una función

# %%
def limpia_columna(data_num, columna, veces):
    # Calcular la media y la desviación típica
    media = data_num[columna].mean()
    desviacion_tipica = data_num[columna].std()

    # Definir los límites para identificar outliers
    limite_inferior = media - veces * desviacion_tipica
    limite_superior = media + veces * desviacion_tipica

    # Filtrar los outliers
    outliers = data_num[(data_num[columna] < limite_inferior) | (data_num[columna] > limite_superior)]
    print("Índices de los outliers:", outliers.index)
    no_outliers = data_num[~((data_num[columna] < limite_inferior) | (data_num[columna] > limite_superior))]

    # Imprimir los resultados
    print("Límite inferior:", limite_inferior)
    print("Límite superior:", limite_superior)
    print("Número de outliers:", len(outliers))

    data[columna].loc[outliers.index] = limite_superior
    return data

# %%
datos_limpios = limpia_columna(data_num, "LotArea", 3)
# Out:
# Índices de los outliers: Int64Index([53, 249, 313, 335, 384, 451, 457, 661, 706, 769, 848, 1298, 1396], dtype='int64')
# Límite inferior: -19426.966714945673
# Límite superior: 40460.62287932923
# Número de outliers: 13
# <ipython-input-41-423905bab342>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[columna].loc[outliers.index] = limite_superior

# %% [markdown]
# Comprobamos que se han sustituido los índices 451 y 457

# %%
datos_limpios.loc[450:460, "LotArea"]
# Out:
# 450     5684.000000
# 451    40460.622879
# 452     9303.000000
# 453     9000.000000
# 454     9297.000000
# 455     9600.000000
# 456     4571.000000
# 457    40460.622879
# 458     5100.000000
# 459     7015.000000
# 460     8004.000000
# Name: LotArea, dtype: float64
